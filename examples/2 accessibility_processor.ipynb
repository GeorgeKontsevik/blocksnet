# %% [markdown]
# # Generating intermodal graph and calculating accessibility matrix
#
# BlocksNet uses [IduEdu](https://github.com/DDonnyy/IduEdu) network library to generate city intermodal graph and calculate the accessibility matrix.

# %%
import os
import geopandas as gpd

data_path = "./data"

# %% [markdown]
# ## Read blocks and initialize processor instance

# %%
from blocksnet import AccessibilityProcessor

blocks = gpd.read_parquet(os.path.join(data_path, 'blocks.parquet'))
ap = AccessibilityProcessor(blocks)

# %% [markdown]
# ## Generate an intermodal city graph

# %%
import iduedu

# iduedu.config.set_overpass_url('https://overpass.kumi.systems/api/interpreter')

# %%
graph = ap.get_intermodal_graph()
# Out:
# 2026-02-24 14:27:24.651 | INFO     | Downloading walk network via Overpass ...
# 2026-02-24 14:27:24.653 | INFO     | Downloading routes via Overpass with types subway, trolleybus, bus, tram ...
# 2026-02-24 14:27:31.453 | WARNING  | HTTP 504: retrying in 1.0s (attempt 1/5)
# 2026-02-24 14:29:23.699 | WARNING  | Network exception HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out., retrying in 1.0 (attempt 1/5)
# 2026-02-24 14:29:32.953 | WARNING  | HTTP 504: retrying in 2.0s (attempt 2/5)
# 2026-02-24 14:29:32.716 | WARNING  | Network exception HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out., retrying in 2.0 (attempt 2/5)
# 2026-02-24 14:29:43.494 | WARNING  | HTTP 504: retrying in 4.0s (attempt 3/5)
# 2026-02-24 14:29:54.319 | WARNING  | HTTP 504: retrying in 8.0s (attempt 4/5)
# 2026-02-24 14:30:05.786 | WARNING  | HTTP 504: retrying in 16.0s (attempt 5/5)
# 2026-02-24 14:31:30.321 | WARNING  | Network exception HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out., retrying in 4.0 (attempt 3/5)
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Calculate the accessibility matrix

# %%
acc_mx = ap.get_accessibility_matrix(graph)
acc_mx.head()
# Out:
#        0          1          2         3          4          5          6      \
# 0   0.000000  18.718750   9.234375  17.21875  30.296875  27.390625  30.671875
# 1  17.859375   0.000000  19.015625   7.65625  20.281250  25.250000  25.234375
# 2   9.234375  20.796875   0.000000  20.21875  27.968750  25.062500  28.343750
# 3  15.937500   7.449219  18.421875   0.00000  21.109375  24.984375  27.781250
# 4  31.906250  19.765625  31.734375  21.28125   0.000000  21.781250  23.125000
#
#        7        8        9      ...    16310     16311     16312    16313  \
# 0  23.281250  78.6875  81.2500  ...  76.5625  102.5625   97.5000  132.250
# 1  15.765625  76.8750  79.4375  ...  74.6875  100.7500   95.6875  130.500
# 2  20.953125  71.8750  74.4375  ...  69.7500   95.8125   90.6875  125.500
# 3  16.593750  76.3125  78.8125  ...  74.1250  100.1875   95.0625  129.875
# 4  15.429688  89.5625  92.1250  ...  87.4375  113.5000  108.3750  143.125
#
#       16314    16315    16316    16317    16318     16319
# 0  130.8750  142.125  247.625  228.625  247.625  124.6250
# 1  129.0000  140.250  245.875  226.875  245.875  112.5000
# 2  124.0625  135.375  240.875  221.875  240.875  124.6250
# 3  128.5000  139.750  245.250  226.250  245.250  113.3750
# 4  141.7500  153.000  258.500  239.500  258.500  108.3125
#
# [5 rows x 16320 columns]

# %%
acc_mx.to_pickle(os.path.join(data_path, 'acc_mx.pickle'))
